# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load speech file

# %%
# load data from pickle file
import pickle

pickle_in = open("speeches.pickle", "rb")
speech_df = pickle.load(pickle_in)

# %%
speech_df.head()
# Out:
#          type          speaker  date  \
# 0  convention  Hillary Clinton  2016
# 1  convention      Robert Dole  1996
# 2  convention   George W. Bush  2000
# 3  convention   George W. Bush  2004
# 4  convention      John McCain  2008
#
#                                               speech
# 0  Thank you all for the great convention that we...
# 1  The folks in Hollywood would be happy to know ...
# 2  Thank you. Thank you for this honor. [,],Thank...
# 3  When I said those words 4 years ago, none of u...
# 4  Tonight, I have a privilege given few American...

# %%
speech_text = speech_df['speech']

# %% [markdown]
# ## Pre-processing

# %%
import nltk

# %%
from textblob import TextBlob
from nltk.util import ngrams

from collections import Counter
from operator import itemgetter

counter = Counter()

from nltk.corpus import stopwords
stop = stopwords.words('english')
stop += ['.', ',', '(', ')', "'", '"']
stop = set(stop)

n = 3
for doc in speech_text:
    words = TextBlob(doc.lower()).words  # tokenize words
    words = [w for w in words if w not in stop]   
    bigrams = ngrams(words, n)
    counter += Counter(bigrams)

for phrase, count in counter.most_common(30):
    print('%20s %i' % (" ".join(phrase), count))
# Out:
# citizens united states 183
#       ending june 30 177
# government united states 175
#     year ending june 168
# people united states 161
#     last fiscal year 145
#   fiscal year ending 144
# last session congress 141
#  last annual message 138
# president united states 132
# united states america 116
#  united states great 104
#   part united states 100
# states great britain 89
# congress last session 82
#     next fiscal year 76
# report secretary war 76
#  present fiscal year 75
# report secretary treasury 69
#     year ending 30th 68
#  current fiscal year 67
# united states government 66
# report secretary navy 66
#        ended june 30 65
#      year ended june 64
# constitution united states 62
#     fiscal year 1947 62
# interstate commerce commission 60
#         world war ii 59
#   bank united states 59

# %% [markdown]
# ## VC and LDA

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
count_vectorizer = CountVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    token_pattern="\\b[a-z][a-z]+\\b"
)

# %%
count_vectorizer.fit(speech_text)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='\\b[a-z][a-z]+\\b',
#         tokenizer=None, vocabulary=None)

# %%
counts = count_vectorizer.transform(speech_text)

# %%
from sklearn import decomposition

# %%
n_topics = 15

lda = decomposition.LatentDirichletAllocation(
    n_components=n_topics, 
    learning_method="online", 
    verbose=1, 
    max_iter=5, 
    n_jobs=-1
)

lda.fit(counts)
# Out:
# iteration: 1 of max_iter: 5
# iteration: 2 of max_iter: 5
# iteration: 3 of max_iter: 5
# iteration: 4 of max_iter: 5
# iteration: 5 of max_iter: 5
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_components=15, n_jobs=-1, n_topics=None, perp_tol=0.1,
#              random_state=None, topic_word_prior=None,
#              total_samples=1000000.0, verbose=1)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
print_top_words(lda, count_vectorizer.get_feature_names(), 15)
# Out:
# Topic #0: people world america government country great nation time peace new make party american states let
# Topic #1: america new world people freedom time nation country great years government american let know party
# Topic #2: america people trump donald new government donald trump years american world president nation country know great
# Topic #3: people government america new great american country states time world years work president make shall
# Topic #4: america people world country great years government nation new shall peace time make american americans
# Topic #5: government states united congress people united states year country great public new time american war world
# Topic #6: people world government america american country states new nation president know years great united peace
# Topic #7: government people nation time country world america great states american new united shall party public
# Topic #8: america world people government new country american time united years president americans nation peace war
# Topic #9: people government america nation world country states new american great shall president free years war
# Topic #10: people america world new country american great party states years government nation let peace time
# Topic #11: people world america president government american new nation country peace united years great shall states
# Topic #12: government people new world america american great country states time party future years let party peace
# Topic #13: people government party country great world states america peace new american make nation united power
# Topic #14: people america government great nation world american country party new states time president united just

# %% [markdown]
# ## TFIDF and NMF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
t_vectorizer = TfidfVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    token_pattern="\\b[a-z][a-z]+\\b"
)

t_vectorizer.fit(speech_text)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='\\b[a-z][a-z]+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
t_counts = t_vectorizer.transform(speech_text)

# %%
n_topics = 15

nmf = decomposition.NMF(
    n_components=n_topics,
    max_iter=5
)

nmf.fit(t_counts)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=5,
#   n_components=15, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
print_top_words(nmf, t_vectorizer.get_feature_names(), 10)
# Out:
# Topic #0: states government united states united congress public year country subject general
# Topic #1: america tonight americans people new ve jobs american work children
# Topic #2: government economic federal program world congress people national year farm
# Topic #3: people world government nation shall peace great freedom nations power
# Topic #4: soviet programs year oil world billion energy percent united soviet union
# Topic #5: applause america ve iraq tonight let people applause let congress iraqi
# Topic #6: america world tonight americans united war let american president peace
# Topic #7: people government president constitution union federal energy strategic congress states
# Topic #8: congress vietnam tonight think years year commitments believe surtax kappel
# Topic #9: interstate law business corporations men conditions work interstate commerce man industrial
# Topic #10: ve party republican president democratic platform people audience ll republican party
# Topic #11: iraq terrorists world saddam weapons terror saddam hussein hussein iraqi america
# Topic #12: year public silver gold present treasury notes indian secretary indians
# Topic #13: war mexico enemy british shall peace men united nation savages
# Topic #14: party people republican democratic party democratic tariff convention platform nomination republican party

# %% [markdown]
# ## Max Features

# %%
t_vectorizer = TfidfVectorizer(
    stop_words="english",
    token_pattern="\\b[a-z][a-z]+\\b",
    max_df=0.9
)

t_vectorizer.fit(speech_text)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.9, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='\\b[a-z][a-z]+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
t_counts = t_vectorizer.transform(speech_text)

# %%
n_topics = 30

nmf = decomposition.NMF(
    n_components=n_topics,
    max_iter=5
)

nmf.fit(t_counts)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=5,
#   n_components=30, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
print_top_words(nmf, t_vectorizer.get_feature_names(), 10)
# Out:
# Topic #0: congress year department general secretary report subject service attention law
# Topic #1: america tonight americans jobs let children years world work know
# Topic #2: program economic federal world congress programs year farm development legislation
# Topic #3: world free freedom men peoples let know shall life america
# Topic #4: spain public commerce powers object vessels effect tribes treaty force
# Topic #5: business interstate law corporations work conditions public men industrial man
# Topic #6: applause ve america let budget tonight congress year iraq laughter
# Topic #7: constitution union shall public citizens state powers interests laws constitutional
# Topic #8: party republican platform democratic nomination say convention republicans campaign president
# Topic #9: ve ll don jobs oil soviet know going want didn
# Topic #10: banks gold notes silver currency treasury public year circulation cent
# Topic #11: mexico texas treaty congress mexican minister territory treasury act state
# Topic #12: year billion help congress percent budget million children tax program
# Topic #13: iraq terrorists america terror iraqi saddam terrorist afghanistan hussein freedom
# Topic #14: public general bank indians subject objects provision present measures attention
# Topic #15: shall fighting japanese production victory men forces america hitler axis
# Topic #16: shall congress commission executive action gold islands treaty gentlemen cuba
# Topic #17: energy programs oil strategic percent federal congress spending union president
# Topic #18: democracy life men know faith spirit speaks years democratic problems
# Topic #19: vietnam tonight congress think years commitments year believe america surtax
# Topic #20: enemy british savages prisoners honorable public savage rights citizens command
# Topic #21: shall year present necessary men thought tariff duty treasury vessels
# Topic #22: freedom seek man help god earth heroes growth tax americans
# Topic #23: british orders decrees militia congress edicts neutral council commerce minister
# Topic #24: let america today world generation journey shall god goal oath
# Topic #25: tariff protective products wages trade law free foreign party laws
# Topic #26: ought republic america law agriculture public relief method civilization property
# Topic #27: gentlemen france congress french public intercourse commissioners commerce treaty article
# Topic #28: president presidency office friends prayers house world god love vice
# Topic #29: recovery convention world shall trade economic international inflation industrial emergency

# %% [markdown]
# ## Perp

# %%
from gensim import matutils

# %% [markdown]
# ## Gensim

# %%
# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
# logging for gensim (set to INFO)
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
counts2 = count_vectorizer.transform(speech_text).transpose()

# %%
counts2.shape
# Out:
# (679282, 356)

# %%
corpus = matutils.Sparse2Corpus(counts2)

# %%
id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())

# %%
lda = models.LdaModel(corpus=corpus, num_topics=5, minimum_probability=0.03, id2word=id2word, passes=10)
# Out:
# 2018-05-29 01:38:24,562 : INFO : using symmetric alpha at 0.2
# 2018-05-29 01:38:24,563 : INFO : using symmetric eta at 0.2
# 2018-05-29 01:38:24,652 : INFO : using serial LDA version on this node
# 2018-05-29 01:38:25,077 : INFO : running online (multi-pass) LDA training, 5 topics, 10 passes over the supplied corpus of 356 documents, updating model once every 356 documents, evaluating perplexity every 356 documents, iterating 50x with a convergence threshold of 0.001000
# 2018-05-29 01:38:37,902 : INFO : -15.085 per-word bound, 34760.1 perplexity estimate based on a held-out corpus of 356 documents with 1949992 words
# 2018-05-29 01:38:37,903 : INFO : PROGRESS: pass 0, at document #356/356
# 2018-05-29 01:38:40,674 : INFO : topic #0 (0.200): 0.003*"government" + 0.003*"people" + 0.002*"states" + 0.002*"united" + 0.002*"congress" + 0.002*"world" + 0.002*"great" + 0.001*"new" + 0.001*"war" + 0.001*"united states"
# 2018-05-29 01:38:40,684 : INFO : topic #1 (0.200): 0.003*"states" + 0.003*"government" + 0.002*"congress" + 0.002*"people" + 0.002*"country" + 0.002*"united states" + 0.002*"year" + 0.002*"great" + 0.002*"american" + 0.002*"time"
# 2018-05-29 01:38:40,694 : INFO : topic #2 (0.200): 0.004*"government" + 0.003*"states" + 0.003*"congress" + 0.002*"united states" + 0.002*"people" + 0.002*"united" + 0.002*"new" + 0.002*"public" + 0.002*"year" + 0.002*"world"
# 2018-05-29 01:38:40,703 : INFO : topic #3 (0.200): 0.004*"government" + 0.003*"states" + 0.002*
#  (2,
#   '0.004*"government" + 0.003*"states" + 0.002*"congress" + 0.002*"united" + 0.002*"united states" + 0.002*"year" + 0.002*"people" + 0.002*"country" + 0.002*"great" + 0.002*"new"'),
#  (3,
#   '0.004*"government" + 0.004*"states" + 0.003*"united" + 0.002*"united states" + 0.002*"congress" + 0.002*"public" + 0.002*"country" + 0.002*"year" + 0.002*"great" + 0.002*"people"'),
#  (4,
#   '0.004*"government" + 0.004*"states" + 0.003*"united" + 0.003*"united states" + 0.003*"congress" + 0.002*"people" + 0.002*"country" + 0.002*"great" + 0.002*"year" + 0.002*"public"')]

# %%
# Transform the docs from the word space to the topic space (like "transform" in sklearn)# Trans 
lda_corpus = lda[corpus]
lda_corpus

# %%
# Store the documents' topic vectors in a list so we can take a peak
lda_docs = [doc for doc in lda_corpus]

# %%
# Check out the document vectors in the topic space for the first 5 documents
lda_docs[:5]
# Out:
# [[(0, 0.90283674), (1, 0.09703268)],
#  [(1, 0.9998166)],
#  [(1, 0.9997775)],
#  [(1, 0.34868836), (2, 0.65118355)],
#  [(0, 0.8453238), (1, 0.15451932)]]

# %%
speech_text[5]
# Out:
# 'I do so with humility, deeply moved by the trust you have placed in me. It is a great honor. It is an even greater responsibility.,Tonight I am asking you to join me to walk together to a better future. By my side, I have chosen a man with a big heart from a small town. He represents the best of America, a man who will always make us proud – my friend and America\'s next Vice President, Paul Ryan.,In the days ahead, you will get to know Paul and Janna better. But last night America got to see what I saw in Paul Ryan – a strong and caring leader who is down to earth and confident in the challenge this moment demands.,I love the way he lights up around his kids and how he\'s not embarrassed to show the world how much he loves his mom.,But Paul, I still like the playlist on my iPod better than yours.,Four years ago, I know that many Americans felt a fresh excitement about the possibilities of a new president. That president was not the choice of our party but Americans always come together after elections. We are a good and generous people who are united by so much more than what divides us.,When that hard fought election was over, when the yard signs came down and the television commercials finally came off the air, Americans were eager to go back to work, to live our lives the way Americans always have – optimistic and positive and confident in the future.,That very optimism is uniquely American.,It is what brought us to America. We are a nation of immigrants. We are the children and grandchildren and great-grandchildren of the ones who wanted a better life, the driven ones, the ones who woke up at night hearing that voice telling them that life in that place called America could be better.,They came not just in pursuit of the riches of this world but for the richness of this life.,Freedom.,Freedom of religion.,Freedom to speak their mind.,Freedom to build a life.,And yes, freedom to build a business. With their own hands.,This is the essence of the American experience.,We Americans have always felt a special kinship with the future.,When every new wave of immigrants looked up and saw the Statue of Liberty, or knelt down and kissed the shores of freedom just ninety miles from Castro\'s tyranny, these new Americans surely had many questions. But none doubted that here in America they could build a better life, that in America their children would be more blessed than they.,But today, four years from the excitement of the last election, for the first time, the majority of Americans now doubt that our children will have a better future.,It is not what we were promised.,Every family in America wanted this to be a time when they could get ahead a little more, put aside a little more for college, do more for their elderly mom who\'s living alone now or give a little more to their church or charity.,Every small business wanted these to be their best years ever, when they could hire more, do more for those who had stuck with them through the hard times, open a new store or sponsor that Little League team.,Every new college graduate thought they\'d have a good job by now, a place of their own, and that they could start paying back some of their loans and build for the future.,This is when our nation was supposed to start paying down the national debt and rolling back those massive deficits.,This was the hope and change America voted for.,It\'s not just what we wanted. It\'s not just what we expected.,It\'s what Americans deserved.,You deserved it because during these years, you worked harder than ever before. You deserved it because when it cost more to fill up your car, you cut out movie nights and put in longer hours. Or when you lost that job that paid $22.50 an hour with benefits, you took two jobs at 9 bucks an hour and fewer benefits. You did it because your family depended on you. You did it because you\'re an American and you don\'t quit. You did it because it was what you had to do.,But driving home late from that second job,  ...

# %%
# we can quantify the 'fit' of our model, to compare with other corpora, etc.
lda.log_perplexity(corpus)
# Out:
# 2018-05-29 01:41:06,966 : INFO : -11.683 per-word bound, 3288.6 perplexity estimate based on a held-out corpus of 356 documents with 1949992 words
# -11.68323848639963

# %%
import pyLDAvis
import pyLDAvis.gensim

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda, corpus, id2word)
vis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-09874cc184a6> in <module>()
#       1 # Visualize the topics
#       2 pyLDAvis.enable_notebook()
# ----> 3 vis = pyLDAvis.gensim.prepare(lda, corpus, id2word)
#       4 vis
#
# ~/miniconda3/lib/python3.6/site-packages/pyLDAvis/gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     109     See `pyLDAvis.prepare` for **kwargs.
#     110     """
# --> 111     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     112     return vis_prepare(**opts)
#
# ~/miniconda3/lib/python3.6/site-packages/pyLDAvis/gensim.py in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      23       corpus = gensim.matutils.Sparse2Corpus(corpus_csc)
#      24
# ---> 25    vocab = list(dictionary.token2id.keys())
#      26    # TODO: add the hyperparam to smooth it out? no beta in online LDA impl.. hmm..
#      27    # for now, I'll just make sure we don't ever get zeros...
#
# AttributeError: 'dict' object has no attribute 'token2id'

# %%
id2word
# Out:
# {616268: 'thank',
#  273550: 'great',
#  133403: 'convention',
#  649930: 've',
#  89935: 'chelsea',
#  486999: 'proud',
#  393028: 'mother',
#  668172: 'woman',
#  69550: 'bringing',
#  373308: 'mark',
#  234415: 'family',
#  89259: 'charlotte',
#  23487: 'aidan',
#  671909: 'world',
#  133965: 'conversation',
#  582958: 'started',
#  345071: 'law',
#  354622: 'library',
#  676800: 'years',
#  21017: 'ago',
#  265492: 'going',
#  593273: 'strong',
#  338404: 'know',
#  344224: 'lasted',
#  266148: 'good',
#  622411: 'times',
#  241126: 'filled',
#  332437: 'joy',
#  281796: 'hard',
#  615729: 'tested',
#  267250: 'gotten',
#  669143: 'words',
#  661337: 'way',
#  634891: 'tuesday',
#  407850: 'night',
#  281448: 'happy',
#  225884: 'explainer',
#  90284: 'chief',
#  331117: 'job',
#  272886: 'grateful',
#  531076: 'rest',
#  255343: 'friends',
#  355874: 'lifetime',
#  669371: 'work',
#  70766: 'brought',
#  624424: 'tonight',
#  332084: 'joined',
#  76588: 'campaign',
#  663444: 'week',
#  518419: 'remarkable',
#  284659: 'heard',
#  370071: 'man',
#  292763: 'hope',
#  98926: 'clinton',
#  54983: 'barack',
#  411347: 'obama',
#  27380: 'america',
#  593663: 'stronger',
#  466575: 'president',
#  348353: 'leadership',
#  62159: 'better',
#  255618: 'friendship',
#  614335: 'terrific',
#  651567: 'vice',
#  331788: 'joe',
#  62889: 'biden',
#  580108: 'spoke',
#  62923: 'big',
#  284842: 'heart',
#  432648: 'party',
#  106489: 'commitment',
#  671208: 'working',
#  439388: 'people',
#  341301: 'lady',
#  384887: 'michelle',
#  519128: 'reminded',
#  90806: 'children',
#  660780: 'watching',
#  196415: 'elect',
#  334396: 'just',
#  262994: 'getting',
#  620543: 'tim',
#  336455: 'kaine',
#  574287: 'soon',
#  637698: 'understand',
#  653933: 'virginia',
#  480751: 'promoting',
#  95588: 'city',
#  137649: 'council',
#  376318: 'mayor',
#  271369: 'governor',
#  556790: 'senator',
#  368222: 'make',
#  139026: 'country',
#  656890: 'want',
#  61406: 'bernie',
#  546234: 'sanders',
#  317664: 'inspired',
#  386311: 'millions',
#  29658: 'americans',
#  431377: 'particularly',
#  678715: 'young',
#  619862: 'threw',
#  285155: 'hearts',
#  575067: 'souls',
#  470253: 'primary',
#  190958: 'economic',
#  572284: 'social',
#  335275: 'justice',
#  329526: 'issues',
#  84142: 'center',
#  59961: 'belong',
#  603806: 'supporters',
#  82287: 'cause',
#  404155: 'needs',
#  297193: 'ideas',
#  203996: 'energy',
#  434215: 'passion',
#  635140: 'turn',
#  479129: 'progressive',
#  450340: 'platform',
#  501336: 'real',
#  86808: 'change',
#  674811: 'wrote',
#  352469: 'let',
#  280948: 'happen',
#  102613: 'come',
#  446777: 'philadelphia',
#  63912: 'birthplace',
#  395355: 'nation',
#  281057: 'happened',
#  611132: 'teach',
#  623261: 'today',
#  590807: 'story',
#  647428: 'usually',
#  244908: 'focus',
#  635381: 'turned',
#  99015: 'close',
#  76365: 'came',
#  674372: 'written',
#  523087: 'representatives',
#  644015: 'unruly',
#  101678: 'colonies',
#  383192: 'met',
#  540591: 'road',
#  657338: 'wanted',
#  589374: 'stick',
#  338080: 'king',
#  536673: 'revolution',
#  296341: 'hung',
#  53499: 'balance',
#  57339: 'began',
#  359283: 'listening',
#  113041: 'compromising',
#  242169: 'finding',
#  107362: 'common',
#  492092: 'purpose',
#  620614: 'time',
#  349997: 'left',
#  58007: 'begun',
#  457110: 'possible',
#  581733: 'stand',
#  625002: 'took',
#  141512: 'courage',
#  251812: 'founders',
#  198392: 'embraced',
#  203473: 'enduring',
#  634401: 'truth',
#  390342: 'moment',
#  505691: 'reckoning',
#  460283: 'powerful',
#  247274: 'forces',
#  619638: 'threatening',
#  491237: 'pull',
#  33444: 'apart',
#  66107: 'bonds',
#  633874: 'trust',
#  528961: 'respect',
#  253039: 'fraying',
#  278027: 'guarantees',
#  633696: 'truly',
#  153963: 'decide',
#  539668: 'rise',
#  393334: 'motto',
#  451441: 'pluribus',
#  644577: 'unum',
#  588104: 'stay',
#  633309: 'true',
#  184633: 'donald',
#  633835: 'trump',
#  32497: 'answer',
#  657472: 'wants',
#  181727: 'divide',
#  62751: 'betting',
#  443129: 'perils',
#  64542: 'blind',
#  642975: 'unlimited',
#  479896: 'promise',
#  607889: 'taken',
#  524260: 'republican',
#  362246: 'long',
#  392744: 'morning',
#  385015: 'midnight',
#  237524: 'fear',
#  258657: 'future',
#  161408: 'democratic',
#  252718: 'franklin',
#  159013: 'delano',
#  541469: 'roosevelt',
#  442438: 'perfect',
#  503583: 'rebuke',
#  443103: 'perilous',
#  617167: 'thing',
#  98114: 'clear',
#  229598: 'eyed',
#  19086: 'afraid',
#  86004: 'challenge',
#  71780: 'build',
#  656765: 'wall',
#  318257: 'instead',
#  191604: 'economy',
#  360892: 'll',
#  434940: 'path',
#  95400: 'citizenship',
#  299087: 'immigrants',
#  132018: 'contributing',
#  53910: 'ban',
#  517165: 'religion',
#  25393: 'allies',
#  240516: 'fight',
#  156405: 'defeat',
#  615341: 'terrorism',
#  364507: 'lot',
#  283064: 'haven',
#  435754: 'pay',
#  497608: 'raise',
#  143526: 'crash',
#  313074: 'inequality',
#  359460: 'little',
#  389348: 'mobility',
#  430045: 'paralysis',
#  659972: 'washington',
#  619748: 'threats',
#  290797: 'home',
#  1354: 'abroad',
#  363287: 'look',
#  387890: 'minute',
#  592456: 'strengths',
#  69156: 'bring',
#  379303: 'meet',
#  86264: 'challenges',
#  188967: 'dynamic',
#  181531: 'diverse',
#  624093: 'tolerant',
#  262168: 'generous',
#  385489: 'military',
#  316682: 'innovative',
#  208911: 'entrepreneurs',
#  648948: 'values',
#  253707: 'freedom',
#  209772: 'equality',
#  422108: 'opportunity',
#  45456: 'associated',
#  612076: 'tell',
#  552293: 'secretary',
#  583164: 'state',
#  664324: 'went',
#  138218: 'countries',
#  284566: 'hear',
#  184461: 'don',
#  662425: 'weak',
#  608436: 'takes',
#  58714: 'believe',
#  548602: 'says',
#  243394: 'fix',
#  678220: 'yes',
#  10001: 'actually',
#  98763: 'cleveland',
#  561261: 'set',
#  24272: 'alarm',
#  59956: 'bells',
#  502142: 'really',
#  328811: 'isn',
#  249161: 'forgetting',
#  632793: 'troops',
#  358592: 'lines',
#  452237: 'police',
#  417614: 'officers',
#  242536: 'firefighters',
#  542769: 'run',
#  149360: 'danger',
#  182280: 'doctors',
#  411159: 'nurses',
#  79017: 'care',
#  611243: 'teachers',
#  360245: 'lives',
#  456998: 'possibilities',
#  472932: 'problem',
#  393099: 'mothers',
#  364309: 'lost',
#  653645: 'violence',
#  72042: 'building',
#  393689: 'movement',
#  337284: 'kids',
#  543892: 'safe',
#  547961: 'say',
#  518800: 'remember',
#  251358: 'fought',
#  125930: 'constitution',
#  445387: 'person',
#  458876: 'power',
#  344594: 'later',
#  232889: 'faith',
#  149187: 'dallas',
#  44230: 'assassinations',
#  68175: 'brave',
#  150570: 'david',
#  71163: 'brown',
#  43628: 'asked',
#  108724: 'community',
#  603044: 'support',
#  246392: 'force',
#  376285: 'maybe',
#  331897: 'join',
#  530036: 'responded',
#  400932: 'nearly',
#  35201: 'applied',
#  151315: 'days',
#  286075: 'help',
#  265397: 'goes',
#  66373: 'book',
#  75655: 'called',
#  653261: 'village',
#  363580: 'looked',
#  623053: 'title',
#  285562: 'heck',
#  376472: 'mean',
#  73814: 'business',
#  284097: 'heal',
#  355925: 'lift',
#  625701: 'totally',
#  351980: 'lend',
#  608750: 'talents',
#  26805: 'ambition',
#  369447: 'making',
#  352331: 'lesson',
#  289284: 'history',
#  571264: 'slogan',
#  278816: 'guiding',
#  470595: 'principle',
#  671643: 'works',
#  556890: 'send',
#  549465: 'school',
#  375386: 'matter',
#  679199: 'zip',
#  100164: 'code',
#  359839: 'live',
#  186232: 'dream',
#  186367: 'dreams',
#  499918: 'reach',
#  234022: 'families',
#  108446: 'communities',
#  364773: 'love',
#  633867: 'trumps',
#  282875: 'hate',
#  240758: 'fighting',
#  296240: 'humility',
#  168555: 'determination',
#  67557: 'boundless',
#  117549: 'confidence',
#  2909: 'accept',
#  408300: 'nomination',
#  641760: 'united',
#  584541: 'states',
#  451523: 'podium',
#  406237: 'new',
#  396947: 'national',
#  581326: 'stage',
#  559084: 'served',
#  678553: 'york',
#  523400: 'represented',
#  623165: 'titles',
#  490356: 'public',
#  559251: 'service',
#  190288: 'easier',
#  72354: 'buildings',
#  72024: 'builders',
#  172123: 'different',
#  337556: 'kind',
#  28758: 'american',
#  646479: 'used',
#  625149: 'tools',
#  265181: 'god',
#  260419: 'gave',
#  355032: 'life',
#  488107: 'provided',
#  72503: 'built',
#  259491: 'futures',
#  272293: 'grandfather',
#  670644: 'worked',
#  550645: 'scranton',
#  341074: 'lace',
#  59426: 'believed',
#  171106: 'did',
#  537857: 'right',
#  149030: 'dad',
#  295591: 'hugh',
#  101201: 'college',
#  450596: 'played',
#  246055: 'football',
#  439036: 'penn',
#  206558: 'enlisted',
#  400161: 'navy',
#  438308: 'pearl',
#  281595: 'harbor',
#  657615: 'war',
#  571498: 'small',
#  471446: 'printing',
#  229684: 'fabric',
#  185879: 'draperies',
#  294813: 'hours',
#  568307: 'silkscreens',
#  70744: 'brothers',
#  421902: 'opportunities',
#  184833: 'dorothy',
#  106: 'abandoned',
#  430287: 'parents',
#  263283: 'girl',
#  203031: 'ended',
#  295201: 'housemaid',
#  547478: 'saved',
#  337927: 'kindness',
#  271634: 'grade',
#  611198: 'teacher',
#  547829: 'saw',
#  190897: 'eat',
#  365539: 'lunch',
#  229045: 'extra',
#  245790: 'food',
#  564243: 'share',
#  208213: 'entire',
#  675084: 'year',
#  352388: 'lessons',
#  433654: 'passed',
#  594491: 'stuck',
#  262962: 'gets',
#  604446: 'sure',
#  349005: 'learned',
#  383769: 'methodist',
#  662222: 'ways',
#  156938: 'defense',
#  257421: 'fund',
#  184694: 'door',
#  57235: 'bedford',
#  374560: 'massachusetts',
#  58177: 'behalf',
#  175103: 'disabilities',
#  162002: 'denied',
#  86588: 'chance',
#  379727: 'meeting',
#  664827: 'wheelchair',
#  455149: 'porch',
#  294912: 'house',
#  623932: 'told',
#  53394: 'badly',
#  171495: 'didn',
#  137614: 'couldn',
#  590272: 'stop',
#  618213: 'thinking',
#  266005: 'gone',
#  90600: 'child',
#  569031: 'simply',
#  79982: 'caring',
#  186597: 'drive',
#  478328: 'progress',
#  346616: 'laws',
#  402889: 'need',
#  637877: 'understanding',
#  8223: 'action',
#  260330: 'gathered',
#  231460: 'facts',
#  99771: 'coalition',
#  286642: 'helped',
#  134442: 'convince',
#  119363: 'congress',
#  206966: 'ensure',
#  3361: 'access',
#  192464: 'education',
#  594533: 'students',
#  296792: 'idea',
#  337257: 'kid',
#  175135: 'disability',
#  356323: 'like',
#  588865: 'step',
#  606916: 'swelled',
#  31292: 'anastasia',
#  574179: 'somoza',
#  523517: 'representing',
#  87361: 'changed',
#  267128: 'got',
#  606787: 'sweat',
#  168285: 'details',
#  452609: 'policy',
#  608950: 'talking',
#  216159: 'exact',
#  353185: 'level',
#  347728: 'lead',
#  186590: 'drinking',
#  660819: 'water',
#  244334: 'flint',
#  384900: 'michigan',
#  410237: 'number',
#  381555: 'mental',
#  284147: 'health',
#  230256: 'facilities',
#  327404: 'iowa',
#  136847: 'cost',
#  464457: 'prescription',
#  186929: 'drugs',
#  151715: 'deal',
#  555225: 'seen',
#  543420: 'ryan',
#  392448: 'moore',
#  345049: 'lauren',
#  372029: 'manning',
#  590719: 'stories',
#  419011: 'old',
#  663325: 'wearing',
#  65521: 'body',
#  67804: 'brace',
#  663651: 'weighed',
#  458633: 'pounds',
#  348866: 'leaned',
#  336937: 'kept',
#  449102: 'plan',
#  642146: 'universal',
#  231958: 'failed',
#  348118: 'leaders',
#  431654: 'parties',
#  143581: 'create',
#  319999: 'insurance',
#  477340: 'program',
#  143372: 'covers',
#  386085: 'million',
#  590169: 'stood',
#  271575: 'grace',
#  273428: 'gravely',
#  315980: 'injured',
#  618677: 'thought',
#  152639: 'debbie',
#  580951: 'st',
#  331804: 'john',
#  393945: 'movie',
#  183249: 'dolan',
#  606831: 'sweeney',
#  651720: 'victims',
#  606026: 'survivors',
#  556454: 'senate',
#  530068: 'responders',
#  567433: 'sick',
#  276154: 'ground',
#  679160: 'zero',
#  665037: 'white',
#  569922: 'situation',
#  541376: 'room',
#  141702: 'courageous',
#  154237: 'decision',
#  241422: 'finally',
#  425699: 'osama',
#  63611: 'bin',
#  341259: 'laden',
#  393159: 'motivate',
#  80436: 'carry',
#  655043: 'voices',
#  524373: 'republicans',
#  309583: 'independents',
#  603829: 'supporting',
#  161546: 'democrats',
#  594395: 'struggling',
#  593200: 'striving',
#  598636: 'successful',
#  655512: 'vote',
#  500156: 'reached',
#  385431: 'milestone',
#  372675: 'march',
#  640656: 'union',
#  367786: 'major',
#  408270: 'nominated',
#  582398: 'standing',
#  150507: 'daughter',
#  150631: 'day',
#  272315: 'grandmothers',
#  263308: 'girls',
#  67783: 'boys',
#  380469: 'men',
#  55279: 'barrier',
#  233781: 'falls',
#  98666: 'clears',
#  83520: 'ceilings',
#  570698: 'sky',
#  357328: 'limit',
#  668267: 'women',
#  165728: 'deserves',
#  300951: 'important',
#  674280: 'write',
#  22843: 'ahead',
#  57517: 'begin',
#  617828: 'think',
#  144397: 'credit',
#  165576: 'deserve',
#  547584: 'saving',
#  673738: 'worst',
#  145711: 'crisis',
#  355922: 'lifetimes',
#  416867: 'office',
#  471842: 'private',
#  552749: 'sector',
#  331392: 'jobs',
#  51087: 'auto',
#  312473: 'industry',
#  61467: 'best',
#  546971: 'satisfied',
#  587751: 'status',
#  496454: 'quo',
#  566493: 'shot',
#  230540: 'facing',
#  156032: 'deep',
#  551772: 'seated',
#  473255: 'problems',
#  169528: 'developed',
#  505298: 'recession',
#  588191: 'stayed',
#  508185: 'recovery',
#  238745: 'feel',
#  256362: 'frustrated',
#  258190: 'furious',
#  665946: 'willing',
#  53004: 'awful',
#  443161: 'period',
#  566690: 'showing',
#  200548: 'empower',
#  388535: 'mission',
#  539863: 'rising',
#  656220: 'wages',
#  211284: 'especially',
#  448593: 'places',
#  316538: 'inner',
#  93602: 'cities',
#  626103: 'towns',
#  309676: 'indian',
#  99672: 'coal',
#  499852: 'ravaged',
#  10794: 'addiction',
#  513322: 'regions',
#  290756: 'hollowed',
#  450072: 'plant',
#  99524: 'closures',
#  619952: 'thrives',
#  384960: 'middle',
#  97360: 'class',
#  161084: 'democracy',
#  35562: 'appoint',
#  604366: 'supreme',
#  142358: 'court',
#  335979: 'justices',
#  390901: 'money',
#  454107: 'politics',
#  222039: 'expand',
#  655884: 'voting',
#  538796: 'rights',
#  532084: 'restrict',
#  401454: 'necessary',
#  433259: 'pass',
#  126639: 'constitutional',
#  27112: 'amendment',
#  427823: 'overturn',
#  94184: 'citizens',
#  135848: 'corporations',
#  435275: 'patriotic',
#  534592: 'return',
#  39237: 'aren',
#  674443: 'wrong',
#  610016: 'tax',
#  68606: 'breaks',
#  280003: 'hand',
#  447485: 'pink',
#  571257: 'slips',
#  591394: 'street',
#  25911: 'allowed',
#  674193: 'wreck',
#  366584: 'main',
#  550105: 'science',
#  98792: 'climate',
#  547263: 'save',
#  449680: 'planet',
#  144036: 'creating',
#  436279: 'paying',
#  98002: 'clean',
#  282251: 'hardworking',
#  556027: 'self',
#  156536: 'defeating',
#  315527: 'inhumane',
#  634624: 'try',
#  337241: 'kick',
#  112736: 'comprehensive',
#  299187: 'immigration',
#  511002: 'reform',
#  276847: 'grow',
#  58683: 'beliefs',
#  109231: 'companies',
#  477092: 'profits',
#  428803: 'pad',
#  219294: 'executive',
#  66357: 'bonuses',
#  387249: 'minimum',
#  656052: 'wage',
#  360612: 'living',
#  458695: 'poverty',
#  18625: 'affordable',
#  639565: 'unfair',
#  626357: 'trade',
#  152123: 'deals',
#  91469: 'china',
#  588809: 'steelworkers',
#  51230: 'autoworkers',
#  277285: 'grown',
#  372285: 'manufacturers',
#  553846: 'security',
#  485650: 'protect',
#  154459: 'decisions',
#  665762: 'wife',
#  569688: 'sister',
#  209437: 'equal',
#  416097: 'odd',
#  387922: 'minutes',
#  416613: 'offered',
#  573894: 'solutions',
#  182965: 'doesn',
#  617375: 'things',
#  668773: 'wonder',
#  449865: 'plans',
#  409602: 'noticed',
#  63114: 'biggest',
#  326081: 'investment',
#  297673: 'ii',
#  372513: 'manufacturing',
#  611711: 'technology',
#  316616: 'innovation',
#  315025: 'infrastructure',
#  325594: 'invest',
#  347548: 'lay',
#  251473: 'foundation',
#  628468: 'transform',
#  463873: 'prepare',
#  634903: 'tuition',
#  253070: 'free',
#  152661: 'debt',
#  354012: 'liberate',
#  594501: 'student',
#  297589: 'ignore',
#  153201: 'debts',
#  510704: 'refinance',
#  146481: 'crucial',
#  158703: 'degree',
#  348886: 'learn',
#  570457: 'skill',
#  461723: 'practice',
#  183045: 'doing',
#  74632: 'businesses',
#  66515: 'boost',
#  171572: 'die',
#  430627: 'parking',
#  364629: 'lots',
#  54537: 'banks',
#  688: 'able',
#  428861: 'paid',
#  349314: 'leave',
#  450629: 'playing',
#  78976: 'card',
#  326266: 'investments',
#  569316: 'single',
#  601825: 'super',
#  537407: 'rich',
#  582803: 'start',
#  232474: 'fair',
#  610598: 'taxes',
#  526697: 'resent',
#  598216: 'success',
#  442063: 'percent',
#  259743: 'gains',
#  245100: 'follow',
#  565124: 'ship',
#  427572: 'overseas',
#  60119: 'belongs',
#  298340: 'imagine',
#  569849: 'sitting',
#  575374: 'sounds',
#  468155: 'pretty',
#  68477: 'break',
#  275918: 'gridlock',
#  507773: 'record',
#  24166: 'aisle',
#  630388: 'treaties',
#  344928: 'launch',
#  477927: 'programs',
#  216313: 'exactly',
#  74801: 'businessman',
#  99383: 'closer',
#  562895: 'shall',
#  46708: 'atlantic',
#  385268: 'miles',
#  131419: 'contractors',
#  511941: 'refused',
#  63435: 'bills',
#  544743: 'said',
#  66366: 'boo',
#  403704: 'needed',
#  674070: 'wouldn',
#  589405: 'stiffed',
#  545644: 'sales',
#  447601: 'pitch',
#  666229: 'win',
#  656724: 'walked',
#  52682: 'away',
#  290496: 'holding',
#  53420: 'bag',
#  608996: 'talks',
#  259957: 'game',
#  494039: 'putting',
#  225832: 'explain',
#  348741: 'leads',
#  620359: 'ties',
#  101896: 'colorado',
#  601031: 'suits',
#  384180: 'mexico',
#  258535: 'furniture',
#  635012: 'turkey',
#  418783: 'ohio',
#  447262: 'picture',
#  252226: 'frames',
#  309640: 'india',
#  666569: 'wisconsin',
#  91971: 'choice',
#  229747: 'face',
#  196568: 'election',
#  582764: 'stark',
#  103220: 'comes',
#  500869: 'reading',
#  407535: 'news',
#  634986: 'turbulence',
#  53429: 'baghdad',
#  336450: 'kabul',
#  407790: 'nice',
#  430443: 'paris',
#  71189: 'brussels',
#  545986: 'san',
#  61389: 'bernardino',
#  425608: 'orlando',
#  151971: 'dealing',
#  168894: 'determined',
#  203537: 'enemies',
#  156491: 'defeated',
#  33271: 'anxious',
#  363643: 'looking',
#  503252: 'reassurance',
#  588410: 'steady',
#  657404: 'wanting',
#  348036: 'leader',
#  638095: 'understands',
#  651236: 'veterans',
#  336654: 'keeping',
#  292698: 'honoring',
#  288528: 'highest',
#  471615: 'priority',
#  354744: 'lid',
#  327445: 'iran',
#  410070: 'nuclear',
#  242611: 'firing',
#  204365: 'enforce',
#  328962: 'israel',
#  564201: 'shaped',
#  264503: 'global',
#  21845: 'agreement',
#  290153: 'hold',
#  5193: 'accountable',
#  106663: 'commitments',
#  305699: 'including',
#  399025: 'nato',
#  619262: 'threat',
#  543144: 'russia',
#  341366: 'laid',
#  591206: 'strategy',
#  328198: 'isis',
#  592819: 'strike',
#  546206: 'sanctuaries',
#  23911: 'air',
#  361500: 'local',
#  608522: 'taking',
#  604966: 'surge',
#  320817: 'intelligence',
#  168419: 'detect',
#  468434: 'prevent',
#  47289: 'attacks',
#  179553: 'disrupt',
#  195621: 'efforts',
#  419726: 'online',
#  496953: 'radicalize',
#  668581: 'won',
#  190729: 'easy',
#  496025: 'quick',
#  388959: 'mistake',
#  468167: 'prevail',
#  496515: 'quote',
#  261721: 'generals',
#  618278: 'thinks',
#  339791: 'knows',
#  96765: 'claimed',
#  40191: 'armed',
#  175637: 'disaster',
#  472182: 'privilege',
#  99303: 'closely',
#  560397: 'services',
#  107003: 'committee',
#  629568: 'treasure',
#  208951: 'entrust',
#  103916: 'commander',
#  282057: 'hardest',
#  230097: 'faces',
#  436889: 'peace',
#  152292: 'death',
#  539958: 'risk',
#  558843: 'serve',
#  78709: 'captain',
#  337220: 'khan',
#  574245: 'sons',
#  385200: 'mike',
#  438789: 'pence',
#  373213: 'marines',
#  43346: 'ask',
#  612354: 'temperament',
#  280447: 'handle',
#  541701: 'rough',
#  634926: 'tumble',
#  467351: 'presidential',
#  364001: 'loses',
#  134652: 'cool',
#  571170: 'slightest',
#  490096: 'provocation',
#  625900: 'tough',
#  494988: 'question',
#  522495: 'reporter',
#  86233: 'challenged',
#  152489: 'debate',
#  555519: 'sees',
#  486910: 'protester',
#  497986: 'rally',
#  150071: 'dare',
#  427100: 'oval',
#  53488: 'bait',
#  635631: 'tweet',
#  663100: 'weapons',
#  330100: 'jackie',
#  336842: 'kennedy',
#  147145: 'cuban',
#  388447: 'missile',
#  673577: 'worried',
#  149693: 'dangerous',
#  132239: 'control',
#  531957: 'restraint',
#  419617: 'ones',
#  393597: 'moved',
#  470046: 'pride',
#  591545: 'strength',
#  344222: 'lashing',
#  516958: 'relies',
#  572024: 'smarts',
#  332825: 'judgment',
#  528003: 'resolve',
#  462705: 'precise',
#  591121: 'strategic',
#  34965: 'application',
#  450875: 'pledge',
#  18340: 'afford',
#  451492: 'pocket',
#  278983: 'gun',
#  361445: 'lobby',
#  521283: 'repeal',
#  551852: 'second',
#  279094: 'guns',
#  566580: 'shouldn',
#  447666: 'place',
#  623019: 'tirelessly',
#  530817: 'responsible',
#  428197: 'owners',
#  557161: 'sense',
#  511464: 'reforms',
#  280543: 'hands',
#  145536: 'criminals',
#  615433: 'terrorists',
#  282289: 'harm',
#  ...}
