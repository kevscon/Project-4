# %%
f = open('transcripts/1972-06-23_1.rtf', 'r')
text = f.read()
f.close()

# %%
text
# Out:
# '{\\rtf1\\ansi\\ansicpg1252\\cocoartf1561\\cocoasubrtf400\n{\\fonttbl\\f0\\froman\\fcharset0 Times-Roman;}\n{\\colortbl;\\red255\\green255\\blue255;\\red0\\green0\\blue0;}\n{\\*\\expandedcolortbl;;\\cssrgb\\c0\\c0\\c0;}\n\\margl1440\\margr1440\\vieww10800\\viewh8400\\viewkind0\n\\deftab720\n\\pard\\pardeftab720\\sl280\\partightenfactor0\n\n\\f0\\fs24 \\cf2 \\expnd0\\expndtw0\\kerning0\n\\outl0\\strokewidth0 \\strokec2 TRANSCRIPT OF A RECORDING OF A MEETING BETWEEN THE PRESIDENT AND H.R. HALDEMAN IN THE OVAL OFFICE ON JUNE 23, 1972 FROM 10:04 TO 11:39 AM June 23, 1972 FROM 10:04 TO 11:39 AM 3 ********** HALDEMAN: okay -that\'s fine. Now, on the investigation, you know, the Democratic break-in thing, we\'re back to the-in the, the problem area because the FBI is not under control, because Gray doesn\'t exactly know how to control them, and they have, their investigation is now leading into some productive areas, because they\'ve been able to trace the money, not through the money itself, but through the bank, you know, sources - the banker himself. And, and it goes in some directions we don\'t want it to go. Ah, also there have been some things, like an informant came in off the street to the FBI in Miami, who was a photographer or has a friend who is a photographer who developed some films through this guy, Barker, and the films had pictures of Democratic National Committee letter head documents and things. So I guess, so it\'s things like that that are gonna, that are filtering in. Mitchell came up with yesterday, and John Dean analyzed very carefully last night and concludes, concurs now with Mitchell\'s recommendation that the only way to solve this, and we\'re set up beautifully to do it, ah, in that and that...the only network that paid any attention to it last night was NBC...they did a massive story on the Cuban... PRESIDENT: That\'s right. HALDEMAN: thing. PRESIDENT: Right. HALDEMAN: That the way to handle this now is for us to have Walters call Pat Gray and just say, "Stay the hell out of this...this is ah, business here we don\'t want you to go any further on it." That\'s not an unusual development,... PRESIDENT: Um huh. JUNE 23, 1972 FROM 10:04 TO 11:39 AM 4 HALDEMAN: ...and, uh, that would take care of it. PRESIDENT: What about Pat Gray, ah, you mean he doesn\'t want to? HALDEMAN: Pat does want to. He doesn\'t know how to, and he doesn\'t have, he doesn\'t have any basis for doing it. Given this, he will then have the basis. He\'ll call Mark Felt in, and the two of them ...and Mark Felt wants to cooperate because... PRESIDENT: Yeah. HALDEMAN: he\'s ambitious... PRESIDENT: Yeah. HALDEMAN: Ah, he\'ll call him in and say, "We\'ve got the signal from across the river to, to put the hold on this." And that will fit rather well because the FBI agents who are working the case, at this point, feel that\'s what it is. This is CIA. PRESIDENT: But they\'ve traced the money to \'em. HALDEMAN: Well they have, they\'ve traced to a name, but they haven\'t gotten to the guy yet. PRESIDENT: Would it be somebody here? HALDEMAN: Ken Dahlberg. PRESIDENT: Who the hell is Ken Dahlberg? HALDEMAN: He\'s ah, he gave $25,000 in Minnesota and ah, the check went directly in to this, to this guy Barker. PRESIDENT: Maybe he\'s a ...bum. JUNE 23, 1972 FROM 10:04 TO 11:39 AM 5 PRESIDENT: He didn\'t get this from the committee though, from Stans. HALDEMAN: Yeah. It is. It is. It\'s directly traceable and there\'s some more through some Texas people in--that went to the Mexican bank which they can also trace to the Mexican bank...they\'ll get their names today. And pause) PRESIDENT: Well, I mean, ah, there\'s no way... I\'m just thinking if they don\'t cooperate, what do they say? They they, they were approached by the Cubans. That\'s what Dahlberg has to say, the Texans too. Is that the idea? HALDEMAN: Well, if they will. But then we\'re relying on more and more people all the time. That\'s the problem. And ah, they\'ll stop if we could, if we take ...

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
words = word_tokenize(text)

# %%
stop_words = set(stopwords.words("english"))

# %%
filtered_text = [w for w in words if not w in stop_words]
filtered_text
# Out:
# ['{',
#  '\\rtf1\\ansi\\ansicpg1252\\cocoartf1561\\cocoasubrtf400',
#  '{',
#  '\\fonttbl\\f0\\froman\\fcharset0',
#  'Times-Roman',
#  ';',
#  '}',
#  '{',
#  '\\colortbl',
#  ';',
#  '\\red255\\green255\\blue255',
#  ';',
#  '\\red0\\green0\\blue0',
#  ';',
#  '}',
#  '{',
#  '\\*\\expandedcolortbl',
#  ';',
#  ';',
#  '\\cssrgb\\c0\\c0\\c0',
#  ';',
#  '}',
#  '\\margl1440\\margr1440\\vieww10800\\viewh8400\\viewkind0',
#  '\\deftab720',
#  '\\pard\\pardeftab720\\sl280\\partightenfactor0',
#  '\\f0\\fs24',
#  '\\cf2',
#  '\\expnd0\\expndtw0\\kerning0',
#  '\\outl0\\strokewidth0',
#  '\\strokec2',
#  'TRANSCRIPT',
#  'OF',
#  'A',
#  'RECORDING',
#  'OF',
#  'A',
#  'MEETING',
#  'BETWEEN',
#  'THE',
#  'PRESIDENT',
#  'AND',
#  'H.R',
#  '.',
#  'HALDEMAN',
#  'IN',
#  'THE',
#  'OVAL',
#  'OFFICE',
#  'ON',
#  'JUNE',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  'TO',
#  '11:39',
#  'AM',
#  'June',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  'TO',
#  '11:39',
#  'AM',
#  '3',
#  '**********',
#  'HALDEMAN',
#  ':',
#  'okay',
#  '-that',
#  "'s",
#  'fine',
#  '.',
#  'Now',
#  ',',
#  'investigation',
#  ',',
#  'know',
#  ',',
#  'Democratic',
#  'break-in',
#  'thing',
#  ',',
#  "'re",
#  'back',
#  'the-in',
#  ',',
#  'problem',
#  'area',
#  'FBI',
#  'control',
#  ',',
#  'Gray',
#  "n't",
#  'exactly',
#  'know',
#  'control',
#  ',',
#  ',',
#  'investigation',
#  'leading',
#  'productive',
#  'areas',
#  ',',
#  "'ve",
#  'able',
#  'trace',
#  'money',
#  ',',
#  'money',
#  ',',
#  'bank',
#  ',',
#  'know',
#  ',',
#  'sources',
#  '-',
#  'banker',
#  '.',
#  'And',
#  ',',
#  'goes',
#  'directions',
#  "n't",
#  'want',
#  'go',
#  '.',
#  'Ah',
#  ',',
#  'also',
#  'things',
#  ',',
#  'like',
#  'informant',
#  'came',
#  'street',
#  'FBI',
#  'Miami',
#  ',',
#  'photographer',
#  'friend',
#  'photographer',
#  'developed',
#  'films',
#  'guy',
#  ',',
#  'Barker',
#  ',',
#  'films',
#  'pictures',
#  'Democratic',
#  'National',
#  'Committee',
#  'letter',
#  'head',
#  'documents',
#  'things',
#  '.',
#  'So',
#  'I',
#  'guess',
#  ',',
#  "'s",
#  'things',
#  'like',
#  'gon',
#  'na',
#  ',',
#  'filtering',
#  '.',
#  'Mitchell',
#  'came',
#  'yesterday',
#  ',',
#  'John',
#  'Dean',
#  'analyzed',
#  'carefully',
#  'last',
#  'night',
#  'concludes',
#  ',',
#  'concurs',
#  'Mitchell',
#  "'s",
#  'recommendation',
#  'way',
#  'solve',
#  ',',
#  "'re",
#  'set',
#  'beautifully',
#  ',',
#  'ah',
#  ',',
#  '...',
#  'network',
#  'paid',
#  'attention',
#  'last',
#  'night',
#  'NBC',
#  '...',
#  'massive',
#  'story',
#  'Cuban',
#  '...',
#  'PRESIDENT',
#  ':',
#  'That',
#  "'s",
#  'right',
#  '.',
#  'HALDEMAN',
#  ':',
#  'thing',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Right',
#  '.',
#  'HALDEMAN',
#  ':',
#  'That',
#  'way',
#  'handle',
#  'us',
#  'Walters',
#  'call',
#  'Pat',
#  'Gray',
#  'say',
#  ',',
#  '``',
#  'Stay',
#  'hell',
#  '...',
#  'ah',
#  ',',
#  'business',
#  "n't",
#  'want',
#  'go',
#  '.',
#  "''",
#  'That',
#  "'s",
#  'unusual',
#  'development',
#  ',',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Um',
#  'huh',
#  '.',
#  'JUNE',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  'TO',
#  '11:39',
#  'AM',
#  '4',
#  'HALDEMAN',
#  ':',
#  '...',
#  ',',
#  'uh',
#  ',',
#  'would',
#  'take',
#  'care',
#  '.',
#  'PRESIDENT',
#  ':',
#  'What',
#  'Pat',
#  'Gray',
#  ',',
#  'ah',
#  ',',
#  'mean',
#  "n't",
#  'want',
#  '?',
#  'HALDEMAN',
#  ':',
#  'Pat',
#  'want',
#  '.',
#  'He',
#  "n't",
#  'know',
#  ',',
#  "n't",
#  ',',
#  "n't",
#  'basis',
#  '.',
#  'Given',
#  ',',
#  'basis',
#  '.',
#  'He',
#  "'ll",
#  'call',
#  'Mark',
#  'Felt',
#  ',',
#  'two',
#  '...',
#  'Mark',
#  'Felt',
#  'wants',
#  'cooperate',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Yeah',
#  '.',
#  'HALDEMAN',
#  ':',
#  "'s",
#  'ambitious',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Yeah',
#  '.',
#  'HALDEMAN',
#  ':',
#  'Ah',
#  ',',
#  "'ll",
#  'call',
#  'say',
#  ',',
#  '``',
#  'We',
#  "'ve",
#  'got',
#  'signal',
#  'across',
#  'river',
#  ',',
#  'put',
#  'hold',
#  '.',
#  "''",
#  'And',
#  'fit',
#  'rather',
#  'well',
#  'FBI',
#  'agents',
#  'working',
#  'case',
#  ',',
#  'point',
#  ',',
#  'feel',
#  "'s",
#  '.',
#  'This',
#  'CIA',
#  '.',
#  'PRESIDENT',
#  ':',
#  'But',
#  "'ve",
#  'traced',
#  'money',
#  "'em",
#  '.',
#  'HALDEMAN',
#  ':',
#  'Well',
#  ',',
#  "'ve",
#  'traced',
#  'name',
#  ',',
#  "n't",
#  'gotten',
#  'guy',
#  'yet',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Would',
#  'somebody',
#  '?',
#  'HALDEMAN',
#  ':',
#  'Ken',
#  'Dahlberg',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Who',
#  'hell',
#  'Ken',
#  'Dahlberg',
#  '?',
#  'HALDEMAN',
#  ':',
#  'He',
#  "'s",
#  'ah',
#  ',',
#  'gave',
#  '$',
#  '25,000',
#  'Minnesota',
#  'ah',
#  ',',
#  'check',
#  'went',
#  'directly',
#  ',',
#  'guy',
#  'Barker',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Maybe',
#  "'s",
#  '...',
#  'bum',
#  '.',
#  'JUNE',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  'TO',
#  '11:39',
#  'AM',
#  '5',
#  'PRESIDENT',
#  ':',
#  'He',
#  "n't",
#  'get',
#  'committee',
#  'though',
#  ',',
#  'Stans',
#  '.',
#  'HALDEMAN',
#  ':',
#  'Yeah',
#  '.',
#  'It',
#  '.',
#  'It',
#  '.',
#  'It',
#  "'s",
#  'directly',
#  'traceable',
#  "'s",
#  'Texas',
#  'people',
#  '--',
#  'went',
#  'Mexican',
#  'bank',
#  'also',
#  'trace',
#  'Mexican',
#  'bank',
#  '...',
#  "'ll",
#  'get',
#  'names',
#  'today',
#  '.',
#  'And',
#  'pause',
#  ')',
#  'PRESIDENT',
#  ':',
#  'Well',
#  ',',
#  'I',
#  'mean',
#  ',',
#  'ah',
#  ',',
#  "'s",
#  'way',
#  '...',
#  'I',
#  "'m",
#  'thinking',
#  "n't",
#  'cooperate',
#  ',',
#  'say',
#  '?',
#  'They',
#  ',',
#  'approached',
#  'Cubans',
#  '.',
#  'That',
#  "'s",
#  'Dahlberg',
#  'say',
#  ',',
#  'Texans',
#  '.',
#  'Is',
#  'idea',
#  '?',
#  'HALDEMAN',
#  ':',
#  'Well',
#  ',',
#  '.',
#  'But',
#  "'re",
#  'relying',
#  'people',
#  'time',
#  '.',
#  'That',
#  "'s",
#  'problem',
#  '.',
#  'And',
#  'ah',
#  ',',
#  "'ll",
#  'stop',
#  'could',
#  ',',
#  'take',
#  'step',
#  '.',
#  'PRESIDENT',
#  ':',
#  'All',
#  'right',
#  '.',
#  'Fine',
#  '.',
#  'HALDEMAN',
#  ':',
#  'And',
#  ',',
#  'seem',
#  'feel',
#  'thing',
#  'get',
#  'stop',
#  '?',
#  'PRESIDENT',
#  ':',
#  'Right',
#  ',',
#  'fine',
#  '.',
#  'HALDEMAN',
#  ':',
#  'They',
#  'say',
#  'way',
#  'White',
#  'House',
#  'instructions',
#  '.',
#  'And',
#  "'s",
#  'got',
#  'Helms',
#  ',',
#  'ah',
#  ',',
#  "'s",
#  'name',
#  '...',
#  '?',
#  'Walters',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Walters',
#  '.',
#  'HALDEMAN',
#  ':',
#  'And',
#  'proposal',
#  'would',
#  'Ehrlichman',
#  '(',
#  'coughs',
#  ')',
#  'I',
#  'call',
#  'PRESIDENT',
#  ':',
#  'All',
#  'right',
#  ',',
#  'fine',
#  '.',
#  'HALDEMAN',
#  ':',
#  'say',
#  ',',
#  'ah',
#  '...',
#  'JUNE',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  'TO',
#  '11:39',
#  'AM',
#  '6',
#  'PRESIDENT',
#  ':',
#  'How',
#  'call',
#  ',',
#  'I',
#  'mean',
#  ',',
#  'well',
#  ',',
#  'protected',
#  'Helms',
#  'one',
#  'hell',
#  'lot',
#  'things',
#  '.',
#  'HALDEMAN',
#  ':',
#  'That',
#  "'s",
#  'Ehrlichman',
#  'says',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Of',
#  'course',
#  ',',
#  ',',
#  'Hunt',
#  ',',
#  'will-that',
#  'uncover',
#  'lot',
#  'things',
#  '.',
#  'You',
#  'open',
#  'scab',
#  "'s",
#  'hell',
#  'lot',
#  'things',
#  'feel',
#  'would',
#  'detrimental',
#  'thing',
#  'go',
#  '.',
#  'This',
#  'involves',
#  'Cubans',
#  ',',
#  'Hunt',
#  ',',
#  'lot',
#  'hanky-panky',
#  'nothing',
#  '.',
#  'Well',
#  'hell',
#  ',',
#  'Mitchell',
#  'know',
#  'thing',
#  'much',
#  'degree',
#  '?',
#  'HALDEMAN',
#  ':',
#  'I',
#  'think',
#  '.',
#  'I',
#  "'t",
#  'think',
#  'knew',
#  'details',
#  ',',
#  'I',
#  'think',
#  'knew',
#  '.',
#  'PRESIDENT',
#  ':',
#  'He',
#  "n't",
#  'know',
#  'going',
#  'handled',
#  'though',
#  ',',
#  'Dahlberg',
#  'Texans',
#  'forth',
#  '?',
#  'Well',
#  'asshole',
#  '?',
#  '(',
#  'Unintelligible',
#  ')',
#  'Is',
#  'Liddy',
#  '?',
#  'Is',
#  'fellow',
#  '?',
#  'He',
#  'must',
#  'little',
#  'nuts',
#  '.',
#  'HALDEMAN',
#  ':',
#  'He',
#  '.',
#  'PRESIDENT',
#  ':',
#  'I',
#  'mean',
#  "n't",
#  'well',
#  'screwed',
#  '?',
#  'Is',
#  "n't",
#  'problem',
#  '?',
#  'HALDEMAN',
#  ':',
#  'No',
#  ',',
#  'pressure',
#  ',',
#  'apparently',
#  ',',
#  'get',
#  'information',
#  ',',
#  'got',
#  'pressure',
#  ',',
#  'pushed',
#  'people',
#  'harder',
#  'move',
#  'harder',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Pressure',
#  'Mitchell',
#  '?',
#  'HALDEMAN',
#  ':',
#  'Apparently',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Oh',
#  ',',
#  'Mitchell',
#  ',',
#  'Mitchell',
#  'point',
#  'made',
#  ',',
#  'exactly',
#  'I',
#  'need',
#  '--',
#  'HALDEMAN',
#  ':',
#  'Gemstone',
#  ',',
#  'yeah',
#  '.',
#  'JUNE',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  'TO',
#  '11:39',
#  'AM',
#  '7',
#  'PRESIDENT',
#  ':',
#  'All',
#  'right',
#  ',',
#  'fine',
#  ',',
#  'I',
#  'understand',
#  '.',
#  'We',
#  'wo',
#  "n't",
#  'second-guess',
#  'Mitchell',
#  'rest',
#  '.',
#  'Thank',
#  'God',
#  "n't",
#  'Colson',
#  '.',
#  'HALDEMAN',
#  ':',
#  'The',
#  'FBI',
#  'interviewed',
#  'Colson',
#  'yesterday',
#  '.',
#  'They',
#  'determined',
#  'would',
#  'good',
#  'thing',
#  '.',
#  'PRESIDENT',
#  ':',
#  'Um',
#  'hum',
#  '.',
#  'HALDEMAN',
#  ':',
#  'Ah',
#  ',',
#  'take',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Um',
#  'hum',
#  '.',
#  'HALDEMAN',
#  ':',
#  'An',
#  'interrogation',
#  ',',
#  ',',
#  ',',
#  'FBI',
#  'guys',
#  'working',
#  'case',
#  'concluded',
#  'one',
#  'two',
#  'possibilities',
#  ',',
#  'one',
#  ',',
#  'White',
#  'House',
#  ',',
#  "n't",
#  'think',
#  'anything',
#  'Election',
#  'Committee',
#  ',',
#  'think',
#  'either',
#  'White',
#  'House',
#  'operation',
#  'obscure',
#  'reasons',
#  ',',
#  'non',
#  'political',
#  ',',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Uh',
#  'huh',
#  '.',
#  'HALDEMAN',
#  ':',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Cuban',
#  'thingHALDEMAN',
#  ':',
#  'Cubans',
#  'CIA',
#  '.',
#  'And',
#  'interrogation',
#  ',',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Colson',
#  '.',
#  'HALDEMAN',
#  ':',
#  'Colson',
#  ',',
#  'yesterday',
#  ',',
#  'concluded',
#  'White',
#  'House',
#  ',',
#  'convinced',
#  'CIA',
#  'thing',
#  ',',
#  'CIA',
#  'turn',
#  'would',
#  '...',
#  'PRESIDENT',
#  ':',
#  'Well',
#  ',',
#  'sure',
#  'analysis',
#  ',',
#  'I',
#  "'m",
#  'going',
#  'get',
#  'involved',
#  '.',
#  'I',
#  "'m",
#  '(',
#  'unintelligible',
#  ')',
#  '.',
#  'HALDEMAN',
#  ':',
#  'No',
#  ',',
#  'sir',
#  '.',
#  'We',
#  "n't",
#  'want',
#  '.',
#  'JUNE',
#  '23',
#  ',',
#  '1972',
#  'FROM',
#  '10:04',
#  '11:39',
#  'AM',
#  '8',
#  '(',
#  'repl',
#  '.',
#  '10/28/74',
#  ')',
#  'PRESIDENT',
#  ':',
#  'You',
#  'call',
#  ...]
