# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load speech file

# %%
# load data from pickle file
import pickle

pickle_in = open("speeches.pickle", "rb")
speech_df = pickle.load(pickle_in)

# %%
speech_df.head()
# Out:
#          type          speaker  date  \
# 0  convention  Hillary Clinton  2016
# 1  convention      Robert Dole  1996
# 2  convention   George W. Bush  2000
# 3  convention   George W. Bush  2004
# 4  convention      John McCain  2008
#
#                                               speech
# 0  Thank you all for the great convention that we...
# 1  The folks in Hollywood would be happy to know ...
# 2  Thank you. Thank you for this honor. [,],Thank...
# 3  When I said those words 4 years ago, none of u...
# 4  Tonight, I have a privilege given few American...

# %%
speech_df['tag'] = speech_df['type'] + speech_df['date'].map(str) + speech_df['speaker']

# %%
speech_text = speech_df['speech']

# %% [markdown]
# ## TFIDF and NMF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
t_vectorizer = TfidfVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    token_pattern="\\b[a-z][a-z]+\\b"
)

tfidf_matrix = t_vectorizer.fit_transform(speech_text)

# %%
t_vectorizer.get_feature_names()
# Out:
# ['aa',
#  'aa cases',
#  'aaa',
#  'aaa program',
#  'aana',
#  'aana western',
#  'aar',
#  'aar participants',
#  'aaron',
#  'aaron burr',
#  'aaron just',
#  'aaron life',
#  'aback',
#  'aback thinking',
#  'abandon',
#  'abandon acted',
#  'abandon adjacent',
#  'abandon agenda',
#  'abandon altogether',
#  'abandon asia',
#  'abandon blessings',
#  'abandon cause',
#  'abandon certain',
#  'abandon children',
#  'abandon cities',
#  'abandon citizenship',
#  'abandon claims',
#  'abandon contest',
#  'abandon contract',
#  'abandon crime',
#  'abandon delusions',
#  'abandon desire',
#  'abandon diminish',
#  'abandon disregard',
#  'abandon effect',
#  'abandon effort',
#  'abandon efforts',
#  'abandon evidently',
#  'abandon failed',
#  'abandon false',
#  'abandon far',
#  'abandon fault',
#  'abandon field',
#  'abandon fundamental',
#  'abandon government',
#  'abandon graves',
#  'abandon great',
#  'abandon growth',
#  'abandon habits',
#  'abandon homes',
#  'abandon hope',
#  'abandon idea',
#  'abandon ideals',
#  'abandon imperfect',
#  'abandon instead',
#  'abandon iraqi',
#  'abandon iraqis',
#  'abandon islands',
#  'abandon just',
#  'abandon justify',
#  'abandon levy',
#  'abandon mastery',
#  'abandon measures',
#  'abandon modify',
#  'abandon national',
#  'abandon naval',
#  'abandon nicaragua',
#  'abandon nomadic',
#  'abandon normal',
#  'abandon nuclear',
#  'abandon perceive',
#  'abandon philosophy',
#  'abandon place',
#  'abandon policy',
#  'abandon practice',
#  'abandon practices',
#  'abandon precious',
#  'abandon prey',
#  'abandon prisoners',
#  'abandon proposed',
#  'abandon purposes',
#  'abandon pursuit',
#  'abandon rate',
#  'abandon reasonable',
#  'abandon reciprocity',
#  'abandon relinquish',
#  'abandon report',
#  'abandon responsibilities',
#  'abandon restrictive',
#  'abandon routes',
#  'abandon sectional',
#  'abandon slightest',
#  'abandon splendid',
#  'abandon stand',
#  'abandon stay',
#  'abandon strong',
#  'abandon struggle',
#  'abandon subject',
#  'abandon surest',
#  'abandon theory',
#  'abandon time',
#  'abandon tolerance',
#  'abandon transportation',
#  'abandon unparalleled',
#  'abandon unproductive',
#  'abandon work',
#  'abandoned',
#  'abandoned abandoned',
#  'abandoned acknowledged',
#  'abandoned acting',
#  'abandoned admission',
#  'abandoned adults',
#  'abandoned amendment',
#  'abandoned annual',
#  'abandoned arctic',
#  'abandoned board',
#  'abandoned boats',
#  'abandoned brilliancy',
#  'abandoned british',
#  'abandoned cent',
#  'abandoned certain',
#  'abandoned civilized',
#  'abandoned conclusion',
#  'abandoned consequence',
#  'abandoned consul',
#  'abandoned continuing',
#  'abandoned corners',
#  'abandoned corrupting',
#  'abandoned country',
#  'abandoned desert',
#  'abandoned doorways',
#  'abandoned economics',
#  'abandoned end',
#  'abandoned enemy',
#  'abandoned errors',
#  'abandoned exigencies',
#  'abandoned expedition',
#  'abandoned far',
#  'abandoned farms',
#  'abandoned fear',
#  'abandoned field',
#  'abandoned firmly',
#  'abandoned follow',
#  'abandoned franchises',
#  'abandoned friends',
#  'abandoned general',
#  'abandoned gentlemen',
#  'abandoned gleam',
#  'abandoned government',
#  'abandoned hazardous',
#  'abandoned hold',
#  'abandoned hope',
#  'abandoned hunter',
#  'abandoned increased',
#  'abandoned indignantly',
#  'abandoned industrial',
#  'abandoned inmates',
#  'abandoned joint',
#  'abandoned just',
#  'abandoned lands',
#  'abandoned leave',
#  'abandoned left',
#  'abandoned manner',
#  'abandoned military',
#  'abandoned missions',
#  'abandoned natural',
#  'abandoned naval',
#  'abandoned nearly',
#  'abandoned negotiations',
#  'abandoned new',
#  'abandoned number',
#  'abandoned objection',
#  'abandoned officers',
#  'abandoned old',
#  'abandoned opportunity',
#  'abandoned parents',
#  'abandoned particular',
#  'abandoned people',
#  'abandoned powers',
#  'abandoned private',
#  'abandoned probable',
#  'abandoned problems',
#  'abandoned profligate',
#  'abandoned project',
#  'abandoned protection',
#  'abandoned recourse',
#  'abandoned relieve',
#  'abandoned reservations',
#  'abandoned right',
#  'abandoned sacrifice',
#  'abandoned security',
#  'abandoned severe',
#  'abandoned spain',
#  'abandoned superpowers',
#  'abandoned supplanted',
#  'abandoned thousands',
#  'abandoned trickledown',
#  'abandoned unequal',
#  'abandoned unless',
#  'abandoned unsatisfactory',
#  'abandoned urge',
#  'abandoned urged',
#  'abandoned usual',
#  'abandoned varied',
#  'abandoned various',
#  'abandoned visited',
#  'abandoned wiser',
#  'abandoned years',
#  'abandoning',
#  'abandoning arms',
#  'abandoning bipartisan',
#  'abandoning commitments',
#  'abandoning farm',
#  'abandoning important',
#  'abandoning methods',
#  'abandoning narrow',
#  'abandoning needy',
#  'abandoning non',
#  'abandoning overlooking',
#  'abandoning path',
#  'abandoning south',
#  'abandoning territory',
#  'abandoning traditional',
#  'abandoning tribes',
#  'abandonment',
#  'abandonment abuse',
#  'abandonment armed',
#  'abandonment children',
#  'abandonment claim',
#  'abandonment combinations',
#  'abandonment complaint',
#  'abandonment discriminating',
#  'abandonment duty',
#  'abandonment effort',
#  'abandonment false',
#  'abandonment fellow',
#  'abandonment gold',
#  'abandonment government',
#  'abandonment horrible',
#  'abandonment impairment',
#  'abandonment intelligent',
#  'abandonment just',
#  'abandonment little',
#  'abandonment local',
#  'abandonment mentally',
#  'abandonment moral',
#  'abandonment physical',
#  'abandonment policy',
#  'abandonment practice',
#  'abandonment present',
#  'abandonment principle',
#  'abandonment privateering',
#  'abandonment program',
#  'abandonment protective',
#  'abandonment securities',
#  'abandonment service',
#  'abandonment smaller',
#  'abandonment takes',
#  'abandonment traditional',
#  'abandonment undertaking',
#  'abandonment unnecessary',
#  'abandonment vital',
#  'abandonment work',
#  'abandons',
#  'abandons banking',
#  'abandons reclamations',
#  'abate',
#  'abate benefit',
#  'abate efforts',
#  'abate near',
#  'abate strengthen',
#  'abate tropic',
#  'abated',
#  'abated appear',
#  'abated dealing',
#  'abated effort',
#  'abated old',
#  'abated pestilence',
#  'abatement',
#  'abatement desire',
#  'abatement distrust',
#  'abatement exactions',
#  'abatement modification',
#  'abatement principal',
#  'abatement rights',
#  'abatement satisfaction',
#  'abating',
#  'abating hurried',
#  'abating tended',
#  'abbas',
#  'abbas discuss',
#  'abbreviation',
#  'abbreviation subject',
#  'abdicate',
#  'abdicate power',
#  'abdicated',
#  'abdicated abdicated',
#  'abdicated practices',
#  'abdicated yes',
#  'abdicating',
#  'abdicating fundamental',
#  'abdicating power',
#  'abdication',
#  'abdication duty',
#  'abdication federal',
#  'abdication late',
#  'abdication manchu',
#  'abdication relief',
#  'abdication seek',
#  'abdication trusteeship',
#  'abducted',
#  'abducted promptly',
#  'abduction',
#  'abduction year',
#  'aberdeen',
#  'aberdeen correspondence',
#  'abess',
#  'abess bank',
#  'abet',
#  'abet insurrection',
#  'abet way',
#  'abetted',
#  'abetted tumults',
#  'abettors',
#  'abettors criminal',
#  'abettors good',
#  'abeyance',
#  'abeyance blockade',
#  'abeyance course',
#  'abeyance dissolution',
#  'abeyance great',
#  'abeyance order',
#  'abeyance prospect',
#  'abeyance prudent',
#  'abeyance reason',
#  'abeyance resume',
#  'abhor',
#  'abhor disruptive',
#  'abhor methods',
#  'abhorrence',
#  'abhorrence citizens',
#  'abhorrence lynching',
#  'abhorrence military',
#  'abhorrence tyranny',
#  'abhorrent',
#  'abhorrent act',
#  'abhorrent instinct',
#  'abhorrent relations',
#  'abhorring',
#  'abhorring war',
#  'abhors',
#  'abhors oppression',
#  'abhors separation',
#  'abhors speculation',
#  'abide',
#  'abide act',
#  'abide acts',
#  'abide carry',
#  'abide certain',
#  'abide compact',
#  'abide constitution',
#  'abide decision',
#  'abide dry',
#  'abide explicit',
#  'abide fate',
#  'abide field',
#  'abide fiercer',
#  'abide judgment',
#  'abide law',
#  'abide laws',
#  'abide monroe',
#  'abide reciprocity',
#  'abide relieved',
#  'abide rivalries',
#  'abide test',
#  'abide verdict',
#  'abide wish',
#  'abides',
#  'abides establishment',
#  'abiding',
#  'abiding adults',
#  'abiding american',
#  'abiding bigotry',
#  'abiding citizen',
#  'abiding citizens',
#  'abiding confidence',
#  'abiding conviction',
#  'abiding cooperation',
#  'abiding creed',
#  'abiding criminals',
#  'abiding divisions',
#  'abiding existence',
#  'abiding faith',
#  'abiding foreign',
#  'abiding foundations',
#  'abiding friendship',
#  'abiding god',
#  'abiding group',
#  'abiding high',
#  'abiding honestly',
#  'abiding ideals',
#  'abiding interests',
#  'abiding logic',
#  'abiding love',
#  'abiding make',
#  'abiding maxims',
#  'abiding opportunities',
#  'abiding people',
#  'abiding place',
#  'abiding places',
#  'abiding political',
#  'abiding progressive',
#  'abiding purpose',
#  'abiding realization',
#  'abiding realize',
#  'abiding respect',
#  'abiding sense',
#  'abiding sources',
#  'abiding strength',
#  'abiding violence',
#  'abiding white',
#  'abiding working',
#  'abilities',
#  'abilities communism',
#  'abilities consigned',
#  'abilities continued',
#  'abilities contribute',
#  'abilities countries',
#  'abilities measure',
#  'abilities patriotism',
#  'abilities people',
#  'abilities recognition',
#  'abilities second',
#  'abilities service',
#  'abilities skills',
#  'abilities training',
#  'abilities tried',
#  'abilities unite',
#  'abilities use',
#  'abilities widen',
#  'ability',
#  'ability achieve',
#  'ability act',
#  'ability adhere',
#  'ability adjust',
#  'ability administer',
#  'ability affect',
#  'ability aid',
#  'ability allies',
#  'ability ambition',
#  'ability america',
#  'ability americans',
#  'ability analyze',
#  'ability answer',
#  'ability apply',
#  'ability appoint',
#  'ability arisen',
#  'ability associate',
#  'ability attract',
#  'ability availability',
#  'ability banks',
#  'ability bear',
#  'ability bearing',
#  'ability branch',
#  'ability bring',
#  'ability business',
#  'ability buy',
#  'ability capacity',
#  'ability care',
#  'ability carry',
#  'ability certain',
#  'ability character',
#  'ability children',
#  'ability china',
#  'ability citizens',
#  'ability city',
#  'ability claims',
#  'ability collect',
#  'ability come',
#  'ability command',
#  'ability compete',
#  'ability complete',
#  'ability conceive',
#  'ability conjunction',
#  'ability consume',
#  'ability continue',
#  'ability contrary',
#  'ability contribute',
#  'ability conventional',
#  'ability convert',
#  'ability country',
#  'ability course',
#  'ability culminated',
#  'ability danger',
#  'ability deal',
#  'ability deeply',
#  'ability defend',
#  'ability defense',
#  'ability deliver',
#  'ability democrats',
#  'ability deploy',
#  'ability derive',
#  'ability detect',
#  'ability deter',
#  'ability determination',
#  'ability devotion',
#  'ability discharge',
#  'ability discharged',
#  'ability discretion',
#  'ability dispatch',
#  'ability disposition',
#  'ability districts',
#  'ability duties',
#  'ability duty',
#  'ability earn',
#  'ability educate',
#  'ability employers',
#  'ability energy',
#  'ability enforce',
#  'ability enter',
#  'ability equal',
#  'ability execute',
#  'ability executive',
#  'ability exercise',
#  'ability expand',
#  'ability expeditiously',
#  'ability experience',
#  'ability extend',
#  'ability extent',
#  'ability feed',
#  'ability ferret',
#  'ability fidelity',
#  'ability field',
#  'ability fight',
#  'ability fighting',
#  'ability fiscally',
#  'ability fitness',
#  'ability fliers',
#  'ability force',
#  'ability foremost',
#  'ability free',
#  'ability fulfill',
#  'ability fullness',
#  'ability glad',
#  'ability govern',
#  'ability government',
#  'ability governments',
#  'ability great',
#  'ability greatest',
#  'ability greatly',
#  'ability grow',
#  'ability hand',
#  'ability healing',
#  'ability history',
#  'ability hope',
#  'ability imagination',
#  'ability imperial',
#  'ability improve',
#  'ability incentive',
#  'ability inclination',
#  'ability indefatigable',
#  'ability influence',
#  'ability insist',
#  'ability inspire',
#  'ability integrity',
#  'ability interfere',
#  'ability irrespective',
#  'ability justice',
#  'ability know',
#  'ability knowledge',
#  'ability labor',
#  'ability lead',
#  'ability learn',
#  'ability legislation',
#  'ability lies',
#  'ability loan',
#  'ability local',
#  'ability love',
#  'ability maintain',
#  'ability make',
#  'ability man',
#  'ability master',
#  'ability mechanics',
#  'ability meet',
#  'ability men',
#  'ability mexican',
#  'ability midshipman',
#  'ability minister',
#  'ability minority',
#  'ability modernize',
#  'ability monitor',
#  'ability moral',
#  'ability nation',
#  'ability nations',
#  'ability navy',
#  'ability negotiate',
#  'ability negotiations',
#  'ability order',
#  'ability partake',
#  'ability past',
#  'ability patriotism',
#  'ability pay',
#  'ability people',
#  'ability performed',
#  'ability perseverance',
#  'ability personally',
#  'ability plan',
#  'ability policy',
#  'ability poor',
#  'ability preserve',
#  'ability president',
#  'ability presidents',
#  'ability probably',
#  'ability produce',
#  'ability professional',
#  'ability progress',
#  'ability proof',
#  'ability proposing',
#  'ability prosecute',
#  'ability protect',
#  'ability purchase',
#  'ability purpose',
#  'ability raise',
#  'ability rate',
#  'ability readiness',
#  'ability receives',
#  'ability recovering',
#  'ability reduced',
#  'ability regardless',
#  'ability reinforce',
#  'ability relieve',
#  'ability remain',
#  'ability render',
#  'ability representatives',
#  'ability required',
#  'ability resent',
#  'ability resist',
#  'ability respects',
#  'ability respond',
#  'ability resulted',
#  'ability returns',
#  'ability rewarded',
#  'ability sabotage',
#  'ability satisfaction',
#  'ability satisfied',
#  'ability second',
#  'ability seek',
#  'ability sell',
#  'ability serve',
#  'ability served',
#  'ability shall',
#  'ability shape',
#  'ability shown',
#  'ability single',
#  'ability skill',
#  'ability soundness',
#  'ability special',
#  'ability sphere',
#  'ability splendid',
#  'ability states',
#  'ability steadfast',
#  'ability strength',
#  'ability success',
#  'ability successful',
#  'ability supply',
#  'ability support',
#  'ability sustain',
#  'ability talent',
#  'ability tax',
#  'ability think',
#  'ability time',
#  'ability track',
#  'ability transport',
#  'ability unfavorable',
#  'ability united',
#  'ability unwearied',
#  'ability white',
#  'ability work',
#  'ability zeal',
#  'abject',
#  'abject dependence',
#  'abject farmers',
#  'abject poverty',
#  'abjured',
#  'abjured recent',
#  'ablaze',
#  'ablaze bombed',
#  'ablaze continent',
#  'able',
#  'able accomplish',
#  'able account',
#  'able act',
#  'able action',
#  'able actual',
#  'able add',
#  'able address',
#  'able adhere',
#  'able adjust',
#  'able administer',
#  'able advantage',
#  'able advert',
#  'able advise',
#  'able affirm',
#  'able afford',
#  'able afraid',
#  'able agree',
#  'able ambassador',
#  'able american',
#  'able announce',
#  'able anticipate',
#  'able apply',
#  'able appoint',
#  'able apprise',
#  'able approve',
#  'able arrive',
#  'able assert',
#  'able assist',
#  'able assistants',
#  'able assume',
#  'able assure',
#  'able audience',
#  'able avoid',
#  'able away',
#  'able band',
#  'able bear',
#  'able best',
#  'able bestow',
#  'able bid',
#  'able bodied',
#  'able break',
#  'able bridge',
#  'able bring',
#  'able build',
#  'able buy',
#  'able called',
#  'able care',
#  'able carefully',
#  'able carry',
#  'able cautiously',
#  'able certain',
#  'able choose',
#  'able citizenry',
#  'able citizens',
#  'able civil',
#  'able coerce',
#  'able collect',
#  'able college',
#  'able come',
#  'able command',
#  'able commanders',
#  'able communicate',
#  'able compete',
#  'able complete',
#  'able comply',
#  'able comprehensive',
#  'able conciliatory',
#  'able concur',
#  'able confidently',
#  'able confront',
#  'able congratulate',
#  'able conquer',
#  'able consideration',
#  'able contribute',
#  'able control',
#  'able cooperate',
#  'able cooperation',
#  'able cope',
#  'able counsel',
#  'able count',
#  'able coverage',
#  'able deal',
#  'able decrease',
#  'able deduct',
#  'able defend',
#  'able define',
#  'able depositaries',
#  'able detain',
#  'able determine',
#  'able devise',
#  'able did',
#  'able digest',
#  'able diplomatic',
#  'able direct',
#  'able discover',
#  'able discussions',
#  'able dispose',
#  'able disputants',
#  'able distinguished',
#  'able divide',
#  'able double',
#  'able draw',
#  'able earn',
#  'able easy',
#  'able educate',
#  'able effect',
#  'able effectively',
#  'able effectually',
#  'able efficiency',
#  'able elaborate',
#  'able election',
#  'able embody',
#  'able emphasize',
#  'able employ',
#  'able endure',
#  'able energetic',
#  'able enforce',
#  'able engage',
#  'able enjoy',
#  'able enroll',
#  'able essential',
#  'able establish',
#  'able evade',
#  'able event',
#  'able excellent',
#  'able exchange',
#  'able execute',
#  'able exercise',
#  'able exertions',
#  'able exhaustive',
#  'able expand',
#  'able expenditures',
#  'able experienced',
#  'able express',
#  'able extend',
#  'able face',
#  'able fair',
#  'able faithful',
#  'able feel',
#  'able fly',
#  'able form',
#  'able fortunate',
#  'able friends',
#  'able fulfill',
#  'able furnish',
#  'able gain',
#  'able gallant',
#  'able gives',
#  'able graduate',
#  'able great',
#  'able grow',
#  'able guarantee',
#  'able handle',
#  'able hard',
#  'able hasty',
#  'able head',
#  'able hear',
#  'able help',
#  'able high',
#  'able hold',
#  'able home',
#  'able honest',
#  'able identify',
#  'able ignore',
#  'able ii',
#  'able illustrate',
#  'able immediately',
#  'able immense',
#  'able impair',
#  'able important',
#  'able increase',
#  'able independence',
#  'able inflation',
#  'able influence',
#  'able inform',
#  'able instantly',
#  'able instill',
#  'able instructive',
#  'able insure',
#  'able intelligently',
#  'able interesting',
#  'able intimidate',
#  'able islands',
#  'able job',
#  'able judge',
#  'able kind',
#  'able know',
#  'able land',
#  'able launch',
#  'able lay',
#  'able learn',
#  'able learning',
#  'able leave',
#  'able lift',
#  'able live',
#  'able loan',
#  'able log',
#  'able look',
#  'able maintain',
#  'able make',
#  'able making',
#  'able management',
#  'able master',
#  'able measures',
#  'able medicare',
#  'able meet',
#  'able men',
#  'able mobilize',
#  'able moment',
#  'able nation',
#  'able noble',
#  'able obstruct',
#  'able obtain',
#  'able open',
#  'able opening',
#  'able ought',
#  'able outset',
#  'able overcome',
#  'able pass',
#  'able pay',
#  'able peaceably',
#  'able perceive',
#  'able perform',
#  'able place',
#  'able point',
#  'able practical',
#  'able prepared',
#  'able prescription',
#  'able present',
#  'able preserve',
#  'able prevent',
#  'able problems',
#  'able proceed',
#  'able produce',
#  'able profitably',
#  'able propose',
#  'able protect',
#  'able protection',
#  'able provide',
#  'able purely',
#  'able quickly',
#  'able reach',
#  'able read',
#  'able ready',
#  'able really',
#  'able reap',
#  'able receive',
#  'able recommend',
#  'able recuperate',
#  'able reduce',
#  'able regulate',
#  'able rejoin',
#  'able relieve',
#  'able repeat',
#  'able repel',
#  'able report',
#  'able representative',
#  'able require',
#  'able residence',
#  'able resist',
#  'able respond',
#  'able restore',
#  'able restrain',
#  'able resume',
#  'able retire',
#  'able return',
#  'able reverse',
#  'able review',
#  'able richest',
#  'able safeguard',
#  'able satisfactory',
#  'able satisfy',
#  'able save',
#  'able say',
#  'able secure',
#  'able sell',
#  'able send',
#  'able separate',
#  'able serve',
#  'able set',
#  'able shift',
#  'able shut',
#  'able sight',
#  'able sign',
#  'able single',
#  'able solve',
#  'able spare',
#  'able speak',
#  'able specialists',
#  'able stand',
#  'able state',
#  'able stop',
#  'able strive',
#  'able subject',
#  'able submit',
#  'able succeed',
#  'able succor',
#  'able supply',
#  'able support',
#  'able suppress',
#  'able surmount',
#  'able survive',
#  'able sustain',
#  'able table',
#  'able talk',
#  'able tell',
#  'able time',
#  'able times',
#  'able train',
#  'able transmit',
#  'able trust',
#  ...]

# %%
from sklearn.metrics.pairwise import cosine_similarity

dist = 1 - cosine_similarity(tfidf_matrix)

# %%
dist
# Out:
# array([[ 3.33066907e-15,  8.77271246e-01,  8.79598367e-01, ...,
#          9.85381450e-01,  9.80462786e-01,  9.85607279e-01],
#        [ 8.77271246e-01,  1.04360964e-14,  8.85040808e-01, ...,
#          9.79530696e-01,  9.74863184e-01,  9.79613961e-01],
#        [ 8.79598367e-01,  8.85040808e-01, -7.28306304e-14, ...,
#          9.84836261e-01,  9.80640004e-01,  9.83685649e-01],
#        ...,
#        [ 9.85381450e-01,  9.79530696e-01,  9.84836261e-01, ...,
#          1.46549439e-14,  9.16077675e-01,  9.44966737e-01],
#        [ 9.80462786e-01,  9.74863184e-01,  9.80640004e-01, ...,
#          9.16077675e-01,  4.66293670e-15,  9.32544573e-01],
#        [ 9.85607279e-01,  9.79613961e-01,  9.83685649e-01, ...,
#          9.44966737e-01,  9.32544573e-01,  1.77635684e-15]])
